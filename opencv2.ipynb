# %%
import cv2 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img1 = cv2.imread('Pictures/wallpaper/capgemini.jpg')

# %%
img1.shape
# Out:
# (1080, 1920, 3)

# %%
img1.shape
# Out:
# (1080, 1920, 3)

# %%
img2 = cv2.imread('Pictures/wallpaper/Screenshot 2023-09-01 185842.jpg',0)

# %%
img2.shape
# Out:
# (338, 1552)

# %%
plt.imshow(img2)

# %%
img2 = cv2.cvtColor(img2,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img2)

# %%
ret,img2black = cv2.threshold(img2,140,255,cv2.THRESH_BINARY)

# %%
ret
# Out:
# 200.0

# %%
plt.imshow(img2black, cmap='gray')

# %%
plt.imshow(img2black, cmap='gray')
